# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os
import random
import seaborn as sns
import numpy as np
from PIL import Image
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import KFold
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers

# %%
# IMG_SIZE is determined by EfficientNet model choice
IMG_SIZE = 224
batch_size = 64
NUM_CLASSES = 4
LEARNING_RATE = 0.001

# %%
train_dir = 'C:\\Users\\linkc\\Downloads\\dataset TA\\RiceLeafs\\train'
val_dir = 'C:\\Users\\linkc\\Downloads\\dataset TA\\RiceLeafs\\validation'

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir,
    labels="inferred",
    label_mode="categorical",
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=batch_size,
)
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    val_dir,
    labels="inferred",
    label_mode="categorical",
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=batch_size,
)

class_names = train_ds.class_names
print(class_names)
# Out:
# Found 2684 files belonging to 4 classes.
# Found 671 files belonging to 4 classes.
# ['BrownSpot', 'Healthy', 'Hispa', 'LeafBlast']

# %%
# Get the class labels
class_labels = os.listdir(train_dir)

# Define the figure size and number of rows and columns for the subplots
fig = plt.figure(figsize=(8, 8))
rows = 3
columns = 3

# Generate 9 random images and their corresponding labels
for i in range(1, rows * columns + 1):
    # Choose a random class label
    label = random.choice(class_labels)
    # Get the list of images for the chosen class label
    img_list = os.listdir(os.path.join(train_dir, label))
    # Choose a random image from the list
    img_file = random.choice(img_list)
    # Load the image using Keras' load_img function
    img = load_img(os.path.join(train_dir, label, img_file), target_size=(224, 224))
    # Add the subplot for the current image
    subplot = fig.add_subplot(rows, columns, i)
    # Set the title of the subplot to the current label
    subplot.title.set_text(label)
    # Display the image
    plt.imshow(img)

# Adjust the spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()

# %%
data_augmentation = tf.keras.Sequential(
    [
        tf.keras.layers.RandomRotation(factor=0.15),
        tf.keras.layers.RandomTranslation(height_factor=0.1, width_factor=0.1),
        tf.keras.layers.RandomFlip(),
        tf.keras.layers.RandomContrast(factor=0.1),
    ],
    name="img_augmentation",
)

# %%
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel('ERROR')

# Take one image from the dataset
for image, label in train_ds.take(1):
    img = image[0]
    plt.figure(figsize=(4, 4))
    plt.imshow(img.numpy().astype("uint8"))
    plt.axis("off")
    plt.show()

# Apply each augmentation technique to the image
plt.figure(figsize=(10, 10))
for i, layer in enumerate(data_augmentation.layers):
    augmented_img = layer(tf.expand_dims(img, 0))
    plt.subplot(3, 3, i+1)
    plt.imshow(augmented_img[0].numpy().astype("uint8"))
    plt.axis("off")
    plt.title(layer.name)
plt.show()

# %%
UTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=UTOTUNE)
val_ds = train_ds = train_ds.cache().prefetch(buffer_size=UTOTUNE)

# %%
from tensorflow.keras import layers

normalization_layer = layers.experimental.preprocessing.Rescaling(1./256)
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x),y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]

# %%
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.models import Sequential

strategy = tf.distribute.MirroredStrategy()

with strategy.scope():
    inputs = layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
    x = data_augmentation(inputs)
    outputs = EfficientNetB0(include_top=True, weights=None, classes=NUM_CLASSES)(x)


    model = tf.keras.Model(inputs, outputs)
    model.compile(optimizer=tf.keras.optimizers.RMSprop(learning_rate=LEARNING_RATE),
              loss='categorical_crossentropy',
              metrics=['accuracy'])
    
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  img_augmentation (Sequentia  (None, 224, 224, 3)      0
#  l)
#
#  efficientnetb0 (Functional)  (None, 4)                4054695
#
# =================================================================
# Total params: 4,054,695
# Trainable params: 4,012,672
# Non-trainable params: 42,023
# _________________________________________________________________

# %%
def build_model(num_classes, input_shape):
    inputs = layers.Input(shape=input_shape)
    x = inputs
    model = EfficientNetB0(include_top=False, input_tensor=x, weights="imagenet")

    # Freeze the pretrained weights
    model.trainable = False

    # Rebuild top
    x = layers.GlobalAveragePooling2D(name="avg_pool")(model.output)
    x = layers.BatchNormalization()(x)

    top_dropout_rate = 0.2
    x = layers.Dropout(top_dropout_rate, name="top_dropout")(x)
    outputs = layers.Dense(num_classes, activation="softmax", name="pred")(x)

    # Compile
    model = tf.keras.Model(inputs, outputs, name="EfficientNet")
    model.compile(optimizer=tf.keras.optimizers.RMSprop(learning_rate=LEARNING_RATE),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

    return model

# %%
with strategy.scope():
    model = build_model(num_classes=NUM_CLASSES, input_shape=(IMG_SIZE, IMG_SIZE, 3))

epochs = 40
# epochs = 5

hist = model.fit(train_ds, epochs=epochs, validation_data=val_ds, verbose=2)
# Out:
# Epoch 1/40
# 42/42 - 253s - loss: 1.2167 - accuracy: 0.5037 - val_loss: 1.1195 - val_accuracy: 0.5179 - 253s/epoch - 6s/step
# Epoch 2/40
# 42/42 - 237s - loss: 0.9395 - accuracy: 0.6311 - val_loss: 1.0530 - val_accuracy: 0.5410 - 237s/epoch - 6s/step
# Epoch 3/40
# 42/42 - 237s - loss: 0.8461 - accuracy: 0.6617 - val_loss: 0.9995 - val_accuracy: 0.5622 - 237s/epoch - 6s/step
# Epoch 4/40
# 42/42 - 237s - loss: 0.7953 - accuracy: 0.6826 - val_loss: 0.9448 - val_accuracy: 0.5842 - 237s/epoch - 6s/step
# Epoch 5/40
# 42/42 - 238s - loss: 0.7663 - accuracy: 0.6855 - val_loss: 0.9000 - val_accuracy: 0.6121 - 238s/epoch - 6s/step
# Epoch 6/40
# 42/42 - 242s - loss: 0.7183 - accuracy: 0.7038 - val_loss: 0.8299 - val_accuracy: 0.6494 - 242s/epoch - 6s/step
# Epoch 7/40
# 42/42 - 241s - loss: 0.6878 - accuracy: 0.7187 - val_loss: 0.7646 - val_accuracy: 0.6852 - 241s/epoch - 6s/step
# Epoch 8/40
# 42/42 - 242s - loss: 0.6836 - accuracy: 0.7224 - val_loss: 0.7234 - val_accuracy: 0.7060 - 242s/epoch - 6s/step
# Epoch 9/40
# 42/42 - 235s - loss: 0.6580 - accuracy: 0.7288 - val_loss: 0.6780 - val_accuracy: 0.7250 - 235s/epoch - 6s/step
# Epoch 10/40
# 42/42 - 239s - loss: 0.6605 - accuracy: 0.7314 - val_loss: 0.6291 - val_accuracy: 0.7511 - 239s/epoch - 6s/step
# Epoch 11/40
# 42/42 - 235s - loss: 0.6487 - accuracy: 0.7306 - val_loss: 0.5962 - val_accuracy: 0.7660 - 235s/epoch - 6s/step
# Epoch 12/40
# 42/42 - 238s - loss: 0.6256 - accuracy: 0.7507 - val_loss: 0.5703 - val_accuracy: 0.7753 - 238s/epoch - 6s/step
# Epoch 13/40
# 42/42 - 236s - loss: 0.6198 - accuracy: 0.7444 - val_loss: 0.5405 - val_accuracy: 0.7876 - 236s/epoch - 6s/step
# Epoch 14/40
# 42/42 - 238s - loss: 0.6169 - accuracy: 0.7519 - val_loss: 0.5186 - val_accuracy: 0.7988 - 238s/epoch - 6s/step
# Epoch 15/40
# 42/42 - 239s - loss: 0.6063 - accuracy: 0.7534 - val_loss: 0.5022 - val_accuracy: 0.8040 - 239s/epoch - 6s/step
# Epoch 16/40
# 42/42 - 235s - loss: 0.6047 - accuracy: 0.7474 - val_loss: 0.4851 - val_accuracy: 0.8081 - 235s/epoch - 6s/step
# Epoch 17/40
# 42/42 - 239s - loss: 0.5899 - accuracy: 0.7567 - val_loss: 0.4730 - val_accuracy: 0.8145 - 239s/epoch - 6s/step
# Epoch 18/40
# 42/42 - 236s - loss: 0.5897 - accuracy: 0.7511 - val_loss: 0.4711 - val_accuracy: 0.8130 - 236s/epoch - 6s/step
# Epoch 19/40
# 42/42 - 236s - loss: 0.5914 - accuracy: 0.7575 - val_loss: 0.4635 - val_accuracy: 0.8137 - 236s/epoch - 6s/step
# Epoch 20/40
# 42/42 - 236s - loss: 0.5858 - accuracy: 0.7623 - val_loss: 0.4569 - val_accuracy: 0.8219 - 236s/epoch - 6s/step
# Epoch 21/40
# 42/42 - 240s - loss: 0.5730 - accuracy: 0.7660 - val_loss: 0.4493 - val_accuracy: 0.8241 - 240s/epoch - 6s/step
# Epoch 22/40
# 42/42 - 237s - loss: 0.5913 - accuracy: 0.7597 - val_loss: 0.4423 - val_accuracy: 0.8275 - 237s/epoch - 6s/step
# Epoch 23/40
# 42/42 - 236s - loss: 0.5761 - accuracy: 0.7653 - val_loss: 0.4380 - val_accuracy: 0.8271 - 236s/epoch - 6s/step
# Epoch 24/40
# 42/42 - 239s - loss: 0.5853 - accuracy: 0.7601 - val_loss: 0.4316 - val_accuracy: 0.8320 - 239s/epoch - 6s/step
# Epoch 25/40
# 42/42 - 235s - loss: 0.5698 - accuracy: 0.7627 - val_loss: 0.4294 - val_accuracy: 0.8394 - 235s/epoch - 6s/step
# Epoch 26/40
# 42/42 - 236s - loss: 0.5739 - accuracy: 0.7656 - val_loss: 0.4331 - val_accuracy: 0.8282 - 236s/epoch - 6s/step
# Epoch 27/40
# 42/42 - 238s - loss: 0.5638 - accuracy: 0.7694 - val_loss: 0.4307 - val_accuracy: 0.8368 - 238s/epoch - 6s/step
# Epoch 28/40
# 42/42 - 237s - loss: 0.5732 - accuracy: 0.7679 - val_loss: 0.4263 - val_accuracy: 0.8353 - 237s/epoch - 6s/step
# Epoch 29/40
# 42/42 - 239s - loss: 0.5568 - accuracy: 0.7675 - val_loss: 0.4219 - val_accuracy: 0.8446 - 239s/epoch - 6s/step
# Epoch 30/40
# 42/42 - 238s - loss: 0.5490 - accuracy: 0.7746 - val_loss: 0.4214 - val_accuracy: 0.8353 - 238s/epoch - 6s/step
# Epoch 31/40
# 42/42 - 235s - loss: 0.5591 - accuracy: 0.7675 - val_loss: 0.4227 - val_accuracy: 0.8353 - 235s/epoch - 6s/step
# Epoch 32/40
# 42/42 - 240s - loss: 0.5562 - accuracy: 0.7712 - val_loss: 0.4146 - val_accuracy: 0.8394 - 240s/epoch - 6s/step
# Epoch 33/40
# 42/42 - 236s - loss: 0.5615 - accuracy: 0.7675 - val_loss: 0.4120 - val_accuracy: 0.8420 - 236s/epoch - 6s/step
# Epoch 34/40
# 42/42 - 237s - loss: 0.5385 - accuracy: 0.7727 - val_loss: 0.4076 - val_accuracy: 0.8454 - 237s/epoch - 6s/step
# Epoch 35/40
# 42/42 - 237s - loss: 0.5398 - accuracy: 0.7820 - val_loss: 0.4137 - val_accuracy: 0.8372 - 237s/epoch - 6s/step
# Epoch 36/40
# 42/42 - 238s - loss: 0.5377 - accuracy: 0.7783 - val_loss: 0.4109 - val_accuracy: 0.8383 - 238s/epoch - 6s/step
# Epoch 37/40
# 42/42 - 238s - loss: 0.5564 - accuracy: 0.7724 - val_loss: 0.4069 - val_accuracy: 0.8405 - 238s/epoch - 6s/step
# Epoch 38/40
# 42/42 - 241s - loss: 0.5525 - accuracy: 0.7731 - val_loss: 0.4105 - val_accuracy: 0.8398 - 241s/epoch - 6s/step
# Epoch 39/40
# 42/42 - 234s - loss: 0.5363 - accuracy: 0.7809 - val_loss: 0.4026 - val_accuracy: 0.8409 - 234s/epoch - 6s/step
# Epoch 40/40
# 42/42 - 237s - loss: 0.5426 - accuracy: 0.7809 - val_loss: 0.4041 - val_accuracy: 0.8379 - 237s/epoch - 6s/step

# %%
def plot_hist(hist):
    plt.plot(hist.history["accuracy"])
    plt.plot(hist.history["val_accuracy"])
    plt.title("model accuracy")
    plt.ylabel("accuracy")
    plt.xlabel("epoch")
    plt.legend(["train", "validation"], loc="upper right")
    plt.show()

plot_hist(hist)

# %%
def unfreeze_model(model):
    # We unfreeze the top 20 layers while leaving BatchNorm layers frozen
    for layer in model.layers[-20:]:
        if not isinstance(layer, layers.BatchNormalization):
            layer.trainable = True

    model.compile(optimizer=tf.keras.optimizers.RMSprop(learning_rate=LEARNING_RATE),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

unfreeze_model(model)

epochs = 30
# epochs = 5

hist = model.fit(train_ds, epochs=epochs, validation_data=val_ds, verbose=2)
plot_hist(hist)
# Out:
# Epoch 1/30
# 42/42 - 261s - loss: 1.0422 - accuracy: 0.6416 - val_loss: 1.4158 - val_accuracy: 0.6852 - 261s/epoch - 6s/step
# Epoch 2/30
# 42/42 - 250s - loss: 0.7117 - accuracy: 0.7098 - val_loss: 1.2532 - val_accuracy: 0.6610 - 250s/epoch - 6s/step
# Epoch 3/30
# 42/42 - 251s - loss: 0.6403 - accuracy: 0.7507 - val_loss: 0.9907 - val_accuracy: 0.7317 - 251s/epoch - 6s/step
# Epoch 4/30
# 42/42 - 251s - loss: 0.5457 - accuracy: 0.7809 - val_loss: 0.8273 - val_accuracy: 0.7213 - 251s/epoch - 6s/step
# Epoch 5/30
# 42/42 - 251s - loss: 0.4926 - accuracy: 0.7984 - val_loss: 0.6506 - val_accuracy: 0.7615 - 251s/epoch - 6s/step
# Epoch 6/30
# 42/42 - 252s - loss: 0.4420 - accuracy: 0.8294 - val_loss: 0.4095 - val_accuracy: 0.8323 - 252s/epoch - 6s/step
# Epoch 7/30
# 42/42 - 250s - loss: 0.3962 - accuracy: 0.8458 - val_loss: 0.4754 - val_accuracy: 0.8118 - 250s/epoch - 6s/step
# Epoch 8/30
# 42/42 - 251s - loss: 0.3594 - accuracy: 0.8584 - val_loss: 0.4155 - val_accuracy: 0.8327 - 251s/epoch - 6s/step
# Epoch 9/30
# 42/42 - 252s - loss: 0.3279 - accuracy: 0.8677 - val_loss: 0.3461 - val_accuracy: 0.8513 - 252s/epoch - 6s/step
# Epoch 10/30
# 42/42 - 252s - loss: 0.2815 - accuracy: 0.8893 - val_loss: 0.3295 - val_accuracy: 0.8644 - 252s/epoch - 6s/step
# Epoch 11/30
# 42/42 - 252s - loss: 0.2476 - accuracy: 0.8946 - val_loss: 0.2450 - val_accuracy: 0.9095 - 252s/epoch - 6s/step
# Epoch 12/30
# 42/42 - 251s - loss: 0.2282 - accuracy: 0.9113 - val_loss: 0.2330 - val_accuracy: 0.9106 - 251s/epoch - 6s/step
# Epoch 13/30
# 42/42 - 252s - loss: 0.2290 - accuracy: 0.9110 - val_loss: 0.2623 - val_accuracy: 0.9042 - 252s/epoch - 6s/step
# Epoch 14/30
# 42/42 - 249s - loss: 0.2040 - accuracy: 0.9210 - val_loss: 0.1989 - val_accuracy: 0.9270 - 249s/epoch - 6s/step
# Epoch 15/30
# 42/42 - 252s - loss: 0.1826 - accuracy: 0.9355 - val_loss: 0.1743 - val_accuracy: 0.9385 - 252s/epoch - 6s/step
# Epoch 16/30
# 42/42 - 252s - loss: 0.1632 - accuracy: 0.9370 - val_loss: 0.1992 - val_accuracy: 0.9300 - 252s/epoch - 6s/step
# Epoch 17/30
# 42/42 - 249s - loss: 0.1501 - accuracy: 0.9463 - val_loss: 0.1304 - val_accuracy: 0.9650 - 249s/epoch - 6s/step
# Epoch 18/30
# 42/42 - 251s - loss: 0.1389 - accuracy: 0.9508 - val_loss: 0.1229 - val_accuracy: 0.9575 - 251s/epoch - 6s/step
# Epoch 19/30
# 42/42 - 250s - loss: 0.1382 - accuracy: 0.9508 - val_loss: 0.1192 - val_accuracy: 0.9609 - 250s/epoch - 6s/step
# Epoch 20/30
# 42/42 - 249s - loss: 0.1130 - accuracy: 0.9601 - val_loss: 0.1159 - val_accuracy: 0.9598 - 249s/epoch - 6s/step
# Epoch 21/30
# 42/42 - 250s - loss: 0.1151 - accuracy: 0.9601 - val_loss: 0.1327 - val_accuracy: 0.9553 - 250s/epoch - 6s/step
# Epoch 22/30
# 42/42 - 252s - loss: 0.1037 - accuracy: 0.9650 - val_loss: 0.0937 - val_accuracy: 0.9661 - 252s/epoch - 6s/step
# Epoch 23/30
# 42/42 - 247s - loss: 0.1121 - accuracy: 0.9609 - val_loss: 0.0999 - val_accuracy: 0.9613 - 247s/epoch - 6s/step
# Epoch 24/30
# 42/42 - 251s - loss: 0.0841 - accuracy: 0.9717 - val_loss: 0.1435 - val_accuracy: 0.9590 - 251s/epoch - 6s/step
# Epoch 25/30
# 42/42 - 249s - loss: 0.0944 - accuracy: 0.9691 - val_loss: 0.1611 - val_accuracy: 0.9404 - 249s/epoch - 6s/step
# Epoch 26/30
# 42/42 - 248s - loss: 0.0694 - accuracy: 0.9754 - val_loss: 0.1549 - val_accuracy: 0.9426 - 248s/epoch - 6s/step
# Epoch 27/30
# 42/42 - 253s - loss: 0.0854 - accuracy: 0.9702 - val_loss: 0.1760 - val_accuracy: 0.9445 - 253s/epoch - 6s/step
# Epoch 28/30
# 42/42 - 246s - loss: 0.0922 - accuracy: 0.9676 - val_loss: 0.1110 - val_accuracy: 0.9575 - 246s/epoch - 6s/step
# Epoch 29/30
# 42/42 - 248s - loss: 0.0804 - accuracy: 0.9750 - val_loss: 0.0883 - val_accuracy: 0.9627 - 248s/epoch - 6s/step
# Epoch 30/30
# 42/42 - 253s - loss: 0.0752 - accuracy: 0.9747 - val_loss: 0.0614 - val_accuracy: 0.9788 - 253s/epoch - 6s/step

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import numpy as np 

test_ds = val_ds.batch(batch_size)
y_true = []
y_pred = []
for x, y in val_ds:
    y_true.extend(np.argmax(y, axis=1))
    y_pred.extend(np.argmax(model.predict(x), axis=1))

# Calculate confusion matrix
cm = confusion_matrix(y_true, y_pred)
print(cm)

# Calculate accuracy, precision, and recall
TP = np.diag(cm)
FP = np.sum(cm, axis=0) - TP
FN = np.sum(cm, axis=1) - TP
TN = np.sum(cm) - (TP + FP + FN)
accuracy = np.mean((TP + TN) / (TP + TN + FP + FN))
precision = np.mean(TP / (TP + FP))
recall = np.mean(TP / (TP + FN))
f1_score = 2 * (precision * recall) / (precision + recall)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1_score)

# Visualize confusion matrix
sns.heatmap(cm, annot=True, cmap="Blues", fmt="d", xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()
# Out:
# 2/2 [==============================] - 5s 1s/step
# 2/2 [==============================] - 2s 1s/step
# 2/2 [==============================] - 2s 1s/step
# 2/2 [==============================] - 2s 1s/step
# 2/2 [==============================] - 2s 1s/step
# 2/2 [==============================] - 3s 2s/step
# 2/2 [==============================] - 3s 2s/step
# 2/2 [==============================] - 3s 2s/step
# 2/2 [==============================] - 3s 2s/step
# 2/2 [==============================] - 4s 2s/step
# 2/2 [==============================] - 3s 2s/step
# 2/2 [==============================] - 4s 2s/step
# 2/2 [==============================] - 2s 1s/step
# 2/2 [==============================] - 2s 1s/step
# 2/2 [==============================] - 2s 1s/step
# 2/2 [==============================] - 2s 1s/step
# 2/2 [==============================] - 3s 1s/step
# 2/2 [==============================] - 2s 1s/step
# 2/2 [==============================] - 5s 1s/step
# 2/2 [==============================] - 4s 2s/step
# 2/2 [==============================] - 3s 1s/step
# 2/2 [==============================] - 2s 1s/step
# 2/2 [==============================] - 2s 1s/step
# 2/2 [==============================] - 3s 2s/step
# 2/2 [==============================] - 2s 1s/step
# 2/2 [==============================] - 3s 2s/step
# 2/2 [==============================] - 3s 2s/step
# 2/2 [==============================] - 4s 2s/step
# 2/2 [==============================] - 3s 1s/step
# 2/2 [==============================] - 2s 1s/step
# 2/2 [==============================] - 2s 1s/step
# 2/2 [==============================] - 3s 1s/step
# 2/2 [==============================] - 4s 2s/step
# 2/2 [==============================] - 3s 1s/step
# 2/2 [==============================] - 2s 1s/step
# 2/2 [==============================] - 2s 1s/step
# 2/2 [==============================] - 3s 1s/step
# 2/2 [==============================] - 4s 2s/step
# 2/2 [==============================] - 2s 1s/step
# 2/2 [==============================] - 2s 1s/step
# 2/2 [==============================] - 3s 1s/step
# 2/2 [==============================] - 3s 2s/step
# [[ 418    0    0    0]
#  [   2 1170   13    6]
#  [   1   19  430    2]
#  [   1    7    6  609]]
# Accuracy: 0.9893815201192251
# Precision: 0.978374993470986
# Recall: 0.9778058204255893
# F1-score: 0.9780903241446037

# %%
from sklearn.model_selection import KFold
import tensorflow as tf
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Define the number of folds
n_splits = 5

acc_scores = []
prec_scores = []
rec_scores = []
f1_scores = []

# Split the data into two sets
kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
for i, (train_idx, val_idx) in enumerate(kf.split(train_dir)):  # train_dir is the path to the directory containing training images
    print(f"Fold {i+1}")

    # Create the training and validation datasets for this fold
    train_ds = tf.keras.preprocessing.image_dataset_from_directory(
        train_dir,
        labels="inferred",
        label_mode="categorical",
        image_size=(IMG_SIZE, IMG_SIZE),
        batch_size=batch_size,
        validation_split=0.2,  # use 20% of the data for validation
        subset="training",
        seed=42,
    )

    val_ds = tf.keras.preprocessing.image_dataset_from_directory(
        train_dir,
        labels="inferred",
        label_mode="categorical",
        image_size=(IMG_SIZE, IMG_SIZE),
        batch_size=batch_size,
        validation_split=0.2,
        subset="validation",
        seed=42,
    )

    # Build and compile the model
    with strategy.scope():
        model = build_model(num_classes=NUM_CLASSES, input_shape=(IMG_SIZE, IMG_SIZE, 3))

    # Unfreeze some layers and recompile the model for fine-tuning
    unfreeze_model(model)

    # Fine-tune the model on the training dataset
    epochs = 30
#     epochs = 5
    hist = model.fit(train_ds, epochs=epochs, validation_data=val_ds, verbose=2)

    # Evaluate the model on the validation dataset
    y_true = []
    y_pred = []
    for images, labels in val_ds:
        pred = model.predict(images)
        y_true.extend(tf.argmax(labels, axis=1))
        y_pred.extend(tf.argmax(pred, axis=1))

    acc_scores.append(accuracy_score(y_true, y_pred))
    prec_scores.append(precision_score(y_true, y_pred, average='macro'))
    rec_scores.append(recall_score(y_true, y_pred, average='macro'))
    f1_scores.append(f1_score(y_true, y_pred, average='macro'))

    print("")
    print("================================================================================")
    print(f"Validation accuracy after fine-tuning: {acc_scores[-1]:.4f}")
    print(f"Validation precision after fine-tuning: {prec_scores[-1]:.4f}")
    print(f"Validation recall after fine-tuning: {rec_scores[-1]:.4f}")
    print(f"Validation F1 score after fine-tuning: {f1_scores[-1]:.4f}")
    print("================================================================================")
    print("")

# Calculate the average scores across all folds
print("")
print("================================================================================")
print(f"Average accuracy: {sum(acc_scores) / len(acc_scores):.4f}")
print(f"Average precision: {sum(prec_scores) / len(prec_scores):.4f}")
print(f"Average recall: {sum(rec_scores) / len(rec_scores):.4f}")
print(f"Average F1 score: {sum(f1_scores) / len(f1_scores):.4f}")
# Out:
# Fold 1
# Found 2684 files belonging to 4 classes.
# Using 2148 files for training.
# Found 2684 files belonging to 4 classes.
# Using 536 files for validation.
# Epoch 1/30
# 34/34 - 184s - loss: 1.1835 - accuracy: 0.5838 - val_loss: 0.9325 - val_accuracy: 0.5951 - 184s/epoch - 5s/step
# Epoch 2/30
# 34/34 - 172s - loss: 0.7798 - accuracy: 0.6941 - val_loss: 0.9368 - val_accuracy: 0.6175 - 172s/epoch - 5s/step
# Epoch 3/30
# 34/34 - 173s - loss: 0.6782 - accuracy: 0.7309 - val_loss: 0.9053 - val_accuracy: 0.6269 - 173s/epoch - 5s/step
# Epoch 4/30
# 34/34 - 170s - loss: 0.6223 - accuracy: 0.7477 - val_loss: 0.8121 - val_accuracy: 0.6810 - 170s/epoch - 5s/step
# Epoch 5/30
# 34/34 - 176s - loss: 0.5659 - accuracy: 0.7682 - val_loss: 1.0695 - val_accuracy: 0.6138 - 176s/epoch - 5s/step
# Epoch 6/30
# 34/34 - 8716s - loss: 0.5107 - accuracy: 0.8012 - val_loss: 1.0636 - val_accuracy: 0.6549 - 8716s/epoch - 256s/step
# Epoch 7/30
# 34/34 - 152s - loss: 0.4827 - accuracy: 0.8096 - val_loss: 0.8157 - val_accuracy: 0.6996 - 152s/epoch - 4s/step
# Epoch 8/30
# 34/34 - 163s - loss: 0.4433 - accuracy: 0.8236 - val_loss: 0.8597 - val_accuracy: 0.6716 - 163s/epoch - 5s/step
# Epoch 9/30
# 34/34 - 176s - loss: 0.4059 - accuracy: 0.8385 - val_loss: 0.7896 - val_accuracy: 0.7146 - 176s/epoch - 5s/step
# Epoch 10/30
# 34/34 - 170s - loss: 0.3607 - accuracy: 0.8594 - val_loss: 0.8485 - val_accuracy: 0.7090 - 170s/epoch - 5s/step
# Epoch 11/30
# 34/34 - 170s - loss: 0.3310 - accuracy: 0.8692 - val_loss: 0.7498 - val_accuracy: 0.7090 - 170s/epoch - 5s/step
# Epoch 12/30
# 34/34 - 169s - loss: 0.3071 - accuracy: 0.8841 - val_loss: 1.2500 - val_accuracy: 0.6269 - 169s/epoch - 5s/step
# Epoch 13/30
# 34/34 - 170s - loss: 0.2969 - accuracy: 0.8883 - val_loss: 0.8878 - val_accuracy: 0.7276 - 170s/epoch - 5s/step
# Epoch 14/30
# 34/34 - 171s - loss: 0.2600 - accuracy: 0.8929 - val_loss: 0.8000 - val_accuracy: 0.7220 - 171s/epoch - 5s/step
# Epoch 15/30
# 34/34 - 169s - loss: 0.2557 - accuracy: 0.8957 - val_loss: 1.1191 - val_accuracy: 0.6959 - 169s/epoch - 5s/step
# Epoch 16/30
# 34/34 - 169s - loss: 0.2093 - accuracy: 0.9185 - val_loss: 1.0527 - val_accuracy: 0.7276 - 169s/epoch - 5s/step
# Epoch 17/30
# 34/34 - 173s - loss: 0.1816 - accuracy: 0.9288 - val_loss: 0.8015 - val_accuracy: 0.6791 - 173s/epoch - 5s/step
# Epoch 18/30
# 34/34 - 172s - loss: 0.1846 - accuracy: 0.9292 - val_loss: 1.0963 - val_accuracy: 0.6940 - 172s/epoch - 5s/step
# Epoch 19/30
# 34/34 - 172s - loss: 0.1726 - accuracy: 0.9399 - val_loss: 1.2225 - val_accuracy: 0.6604 - 172s/epoch - 5s/step
# Epoch 20/30
# 34/34 - 174s - loss: 0.1742 - accuracy: 0.9330 - val_loss: 1.1587 - val_accuracy: 0.6978 - 174s/epoch - 5s/step
# Epoch 21/30
# 34/34 - 184s - loss: 0.1460 - accuracy: 0.9488 - val_loss: 1.3122 - val_accuracy: 0.7034 - 184s/epoch - 5s/step
# Epoch 22/30
# 34/34 - 186s - loss: 0.1365 - accuracy: 0.9530 - val_loss: 1.2605 - val_accuracy: 0.7295 - 186s/epoch - 5s/step
# Epoch 23/30
# 34/34 - 175s - loss: 0.1618 - accuracy: 0.9423 - val_loss: 1.4137 - val_accuracy: 0.6679 - 175s/epoch - 5s/step
# Epoch 24/30
# 34/34 - 170s - loss: 0.1159 - accuracy: 0.9586 - val_loss: 1.6013 - val_accuracy: 0.6884 - 170s/epoch - 5s/step
# Epoch 25/30
# 34/34 - 175s - loss: 0.1213 - accuracy: 0.9600 - val_loss: 1.2598 - val_accuracy: 0.6959 - 175s/epoch - 5s/step
# Epoch 26/30
# 34/34 - 171s - loss: 0.1099 - accuracy: 0.9604 - val_loss: 1.4201 - val_accuracy: 0.7090 - 171s/epoch - 5s/step
# Epoch 27/30
# 34/34 - 170s - loss: 0.1236 - accuracy: 0.9558 - val_loss: 1.0864 - val_accuracy: 0.7332 - 170s/epoch - 5s/step
# Epoch 28/30
# 34/34 - 169s - loss: 0.0908 - accuracy: 0.9688 - val_loss: 1.3873 - val_accuracy: 0.7257 - 169s/epoch - 5s/step
# Epoch 29/30
# 34/34 - 174s - loss: 0.1017 - accuracy: 0.9660 - val_loss: 1.7063 - val_accuracy: 0.7108 - 174s/epoch - 5s/step
# Epoch 30/30
# 34/34 - 168s - loss: 0.1034 - accuracy: 0.9646 - val_loss: 1.5324 - val_accuracy: 0.7220 - 168s/epoch - 5s/step
# 2/2 [==============================] - 5s 1s/step
# 2/2 [==============================] - 4s 2s/step
# 2/2 [==============================] - 3s 1s/step
# 2/2 [==============================] - 2s 1s/step
# 2/2 [==============================] - 2s 1s/step
# 2/2 [==============================] - 3s 2s/step
# 2/2 [==============================] - 3s 2s/step
# 2/2 [==============================] - 4s 2s/step
# 1/1 [==============================] - 3s 3s/step
#
# ================================================================================
# Validation accuracy after fine-tuning: 0.7220
# Validation precision after fine-tuning: 0.7138
# Validation recall after fine-tuning: 0.6724
# Validation F1 score after fine-tuning: 0.6658
# ================================================================================
#
# Fold 2
# Found 2684 files belonging to 4 classes.
# Using 2148 files for training.
# Found 2684 files belonging to 4 classes.
# Using 536 files for validation.
# Epoch 1/30
# 34/34 - 183s - loss: 1.1648 - accuracy: 0.5857 - val_loss: 1.2392 - val_accuracy: 0.5317 - 183s/epoch - 5s/step
# Epoch 2/30
# 34/34 - 172s - loss: 0.8007 - accuracy: 0.6913 - val_loss: 0.9715 - val_accuracy: 0.5896 - 172s/epoch - 5s/step
# Epoch 3/30
# 34/34 - 173s - loss: 0.7078 - accuracy: 0.7281 - val_loss: 0.8463 - val_accuracy: 0.6623 - 173s/epoch - 5s/step
# Epoch 4/30
# 34/34 - 173s - loss: 0.6370 - accuracy: 0.7360 - val_loss: 0.7951 - val_accuracy: 0.7127 - 173s/epoch - 5s/step
# Epoch 5/30
# 34/34 - 174s - loss: 0.5898 - accuracy: 0.7658 - val_loss: 0.7337 - val_accuracy: 0.6996 - 174s/epoch - 5s/step
# Epoch 6/30
# 34/34 - 176s - loss: 0.5177 - accuracy: 0.7975 - val_loss: 0.8601 - val_accuracy: 0.6847 - 176s/epoch - 5s/step
# Epoch 7/30
# 34/34 - 172s - loss: 0.5042 - accuracy: 0.7961 - val_loss: 0.8171 - val_accuracy: 0.7146 - 172s/epoch - 5s/step
# Epoch 8/30
# 34/34 - 174s - loss: 0.4427 - accuracy: 0.8180 - val_loss: 0.7281 - val_accuracy: 0.7220 - 174s/epoch - 5s/step
# Epoch 9/30
# 34/34 - 175s - loss: 0.4071 - accuracy: 0.8436 - val_loss: 0.7418 - val_accuracy: 0.7146 - 175s/epoch - 5s/step
# Epoch 10/30
# 34/34 - 174s - loss: 0.3865 - accuracy: 0.8478 - val_loss: 0.8516 - val_accuracy: 0.6978 - 174s/epoch - 5s/step
# Epoch 11/30
# 34/34 - 169s - loss: 0.3468 - accuracy: 0.8599 - val_loss: 0.7516 - val_accuracy: 0.7295 - 169s/epoch - 5s/step
# Epoch 12/30
# 34/34 - 173s - loss: 0.3117 - accuracy: 0.8762 - val_loss: 0.8412 - val_accuracy: 0.7220 - 173s/epoch - 5s/step
# Epoch 13/30
# 34/34 - 175s - loss: 0.2860 - accuracy: 0.8897 - val_loss: 1.0082 - val_accuracy: 0.6959 - 175s/epoch - 5s/step
# Epoch 14/30
# 34/34 - 182s - loss: 0.2653 - accuracy: 0.8850 - val_loss: 0.8869 - val_accuracy: 0.7127 - 182s/epoch - 5s/step
# Epoch 15/30
# 34/34 - 180s - loss: 0.2563 - accuracy: 0.8999 - val_loss: 0.9066 - val_accuracy: 0.7146 - 180s/epoch - 5s/step
# Epoch 16/30
# 34/34 - 179s - loss: 0.1964 - accuracy: 0.9223 - val_loss: 0.9746 - val_accuracy: 0.7295 - 179s/epoch - 5s/step
# Epoch 17/30
# 34/34 - 179s - loss: 0.2010 - accuracy: 0.9264 - val_loss: 0.9852 - val_accuracy: 0.6698 - 179s/epoch - 5s/step
# Epoch 18/30
# 34/34 - 184s - loss: 0.1771 - accuracy: 0.9320 - val_loss: 1.0631 - val_accuracy: 0.7425 - 184s/epoch - 5s/step
# Epoch 19/30
# 34/34 - 182s - loss: 0.1842 - accuracy: 0.9367 - val_loss: 1.3371 - val_accuracy: 0.6418 - 182s/epoch - 5s/step
# Epoch 20/30
# 34/34 - 179s - loss: 0.1668 - accuracy: 0.9409 - val_loss: 0.8903 - val_accuracy: 0.7369 - 179s/epoch - 5s/step
# Epoch 21/30
# 34/34 - 180s - loss: 0.1621 - accuracy: 0.9399 - val_loss: 1.0848 - val_accuracy: 0.7519 - 180s/epoch - 5s/step
# Epoch 22/30
# 34/34 - 182s - loss: 0.1476 - accuracy: 0.9460 - val_loss: 1.1659 - val_accuracy: 0.7463 - 182s/epoch - 5s/step
# Epoch 23/30
# 34/34 - 179s - loss: 0.1464 - accuracy: 0.9465 - val_loss: 1.1222 - val_accuracy: 0.7537 - 179s/epoch - 5s/step
# Epoch 24/30
# 34/34 - 185s - loss: 0.1133 - accuracy: 0.9604 - val_loss: 1.3773 - val_accuracy: 0.7575 - 185s/epoch - 5s/step
# Epoch 25/30
# 34/34 - 179s - loss: 0.1211 - accuracy: 0.9581 - val_loss: 1.1163 - val_accuracy: 0.7425 - 179s/epoch - 5s/step
# Epoch 26/30
# 34/34 - 180s - loss: 0.1300 - accuracy: 0.9544 - val_loss: 1.2688 - val_accuracy: 0.6791 - 180s/epoch - 5s/step
# Epoch 27/30
# 34/34 - 178s - loss: 0.1119 - accuracy: 0.9562 - val_loss: 1.1490 - val_accuracy: 0.7500 - 178s/epoch - 5s/step
# Epoch 28/30
# 34/34 - 182s - loss: 0.1074 - accuracy: 0.9595 - val_loss: 1.3793 - val_accuracy: 0.7537 - 182s/epoch - 5s/step
# Epoch 29/30
# 34/34 - 179s - loss: 0.1107 - accuracy: 0.9567 - val_loss: 1.4849 - val_accuracy: 0.7369 - 179s/epoch - 5s/step
# Epoch 30/30
# 34/34 - 181s - loss: 0.1044 - accuracy: 0.9572 - val_loss: 1.1910 - val_accuracy: 0.7332 - 181s/epoch - 5s/step
# 2/2 [==============================] - 4s 1s/step
# 2/2 [==============================] - 3s 1s/step
# 2/2 [==============================] - 3s 1s/step
# 2/2 [==============================] - 3s 1s/step
# 2/2 [==============================] - 3s 1s/step
# 2/2 [==============================] - 4s 2s/step
# 2/2 [==============================] - 3s 1s/step
# 2/2 [==============================] - 4s 2s/step
# 1/1 [==============================] - 4s 4s/step
#
# ================================================================================
# Validation accuracy after fine-tuning: 0.7332
# Validation precision after fine-tuning: 0.7109
# Validation recall after fine-tuning: 0.7128
# Validation F1 score after fine-tuning: 0.7073
# ================================================================================
#
# Fold 3
# Found 2684 files belonging to 4 classes.
# Using 2148 files for training.
# Found 2684 files belonging to 4 classes.
# Using 536 files for validation.
# Epoch 1/30
# 34/34 - 213s - loss: 1.0927 - accuracy: 0.5936 - val_loss: 1.0720 - val_accuracy: 0.5578 - 213s/epoch - 6s/step
# Epoch 2/30
# 34/34 - 187s - loss: 0.7663 - accuracy: 0.6848 - val_loss: 1.2097 - val_accuracy: 0.5056 - 187s/epoch - 6s/step
# Epoch 3/30
# 34/34 - 183s - loss: 0.6986 - accuracy: 0.7053 - val_loss: 1.3499 - val_accuracy: 0.5317 - 183s/epoch - 5s/step
# Epoch 4/30
# 34/34 - 176s - loss: 0.6367 - accuracy: 0.7533 - val_loss: 0.7873 - val_accuracy: 0.6940 - 176s/epoch - 5s/step
# Epoch 5/30
# 34/34 - 179s - loss: 0.5647 - accuracy: 0.7663 - val_loss: 0.7719 - val_accuracy: 0.7201 - 179s/epoch - 5s/step
# Epoch 6/30
# 34/34 - 177s - loss: 0.5424 - accuracy: 0.7863 - val_loss: 1.2631 - val_accuracy: 0.6026 - 177s/epoch - 5s/step
# Epoch 7/30
# 34/34 - 178s - loss: 0.4999 - accuracy: 0.7984 - val_loss: 0.8961 - val_accuracy: 0.6959 - 178s/epoch - 5s/step
# Epoch 8/30
# 34/34 - 176s - loss: 0.4599 - accuracy: 0.8152 - val_loss: 1.0813 - val_accuracy: 0.6530 - 176s/epoch - 5s/step
# Epoch 9/30
# 34/34 - 178s - loss: 0.4116 - accuracy: 0.8440 - val_loss: 0.8540 - val_accuracy: 0.6978 - 178s/epoch - 5s/step
# Epoch 10/30
# 34/34 - 175s - loss: 0.3696 - accuracy: 0.8506 - val_loss: 0.9206 - val_accuracy: 0.6828 - 175s/epoch - 5s/step
# Epoch 11/30
# 34/34 - 177s - loss: 0.3665 - accuracy: 0.8538 - val_loss: 0.7121 - val_accuracy: 0.7425 - 177s/epoch - 5s/step
# Epoch 12/30
# 34/34 - 178s - loss: 0.3164 - accuracy: 0.8818 - val_loss: 0.8058 - val_accuracy: 0.6772 - 178s/epoch - 5s/step
# Epoch 13/30
# 34/34 - 177s - loss: 0.2915 - accuracy: 0.8873 - val_loss: 0.8937 - val_accuracy: 0.7127 - 177s/epoch - 5s/step
# Epoch 14/30
# 34/34 - 178s - loss: 0.2679 - accuracy: 0.8980 - val_loss: 0.8271 - val_accuracy: 0.7220 - 178s/epoch - 5s/step
# Epoch 15/30
# 34/34 - 179s - loss: 0.2572 - accuracy: 0.9004 - val_loss: 0.9571 - val_accuracy: 0.7108 - 179s/epoch - 5s/step
# Epoch 16/30
# 34/34 - 180s - loss: 0.2111 - accuracy: 0.9190 - val_loss: 1.0250 - val_accuracy: 0.7220 - 180s/epoch - 5s/step
# Epoch 17/30
# 34/34 - 179s - loss: 0.2070 - accuracy: 0.9255 - val_loss: 1.0044 - val_accuracy: 0.6754 - 179s/epoch - 5s/step
# Epoch 18/30
# 34/34 - 178s - loss: 0.1785 - accuracy: 0.9302 - val_loss: 1.0297 - val_accuracy: 0.7164 - 178s/epoch - 5s/step
# Epoch 19/30
# 34/34 - 178s - loss: 0.1949 - accuracy: 0.9236 - val_loss: 1.4086 - val_accuracy: 0.6213 - 178s/epoch - 5s/step
# Epoch 20/30
# 34/34 - 179s - loss: 0.1898 - accuracy: 0.9274 - val_loss: 0.9689 - val_accuracy: 0.7239 - 179s/epoch - 5s/step
# Epoch 21/30
# 34/34 - 178s - loss: 0.1643 - accuracy: 0.9381 - val_loss: 0.9848 - val_accuracy: 0.6959 - 178s/epoch - 5s/step
# Epoch 22/30
# 34/34 - 179s - loss: 0.1518 - accuracy: 0.9469 - val_loss: 1.2011 - val_accuracy: 0.6996 - 179s/epoch - 5s/step
# Epoch 23/30
# 34/34 - 180s - loss: 0.1271 - accuracy: 0.9558 - val_loss: 0.9841 - val_accuracy: 0.7537 - 180s/epoch - 5s/step
# Epoch 24/30
# 34/34 - 178s - loss: 0.1397 - accuracy: 0.9446 - val_loss: 1.2575 - val_accuracy: 0.7090 - 178s/epoch - 5s/step
# Epoch 25/30
# 34/34 - 181s - loss: 0.1230 - accuracy: 0.9562 - val_loss: 1.2465 - val_accuracy: 0.7295 - 181s/epoch - 5s/step
# Epoch 26/30
# 34/34 - 179s - loss: 0.1190 - accuracy: 0.9525 - val_loss: 1.0227 - val_accuracy: 0.7146 - 179s/epoch - 5s/step
# Epoch 27/30
# 34/34 - 178s - loss: 0.1275 - accuracy: 0.9553 - val_loss: 1.0157 - val_accuracy: 0.7481 - 178s/epoch - 5s/step
# Epoch 28/30
# 34/34 - 178s - loss: 0.0904 - accuracy: 0.9674 - val_loss: 1.4288 - val_accuracy: 0.7369 - 178s/epoch - 5s/step
# Epoch 29/30
# 34/34 - 181s - loss: 0.1248 - accuracy: 0.9609 - val_loss: 1.3185 - val_accuracy: 0.6940 - 181s/epoch - 5s/step
# Epoch 30/30
# 34/34 - 186s - loss: 0.0965 - accuracy: 0.9637 - val_loss: 1.6831 - val_accuracy: 0.7164 - 186s/epoch - 5s/step
# 2/2 [==============================] - 6s 2s/step
# 2/2 [==============================] - 2s 1s/step
# 2/2 [==============================] - 2s 1s/step
# 2/2 [==============================] - 2s 1s/step
# 2/2 [==============================] - 2s 1s/step
# 2/2 [==============================] - 3s 1s/step
# 2/2 [==============================] - 3s 1s/step
# 2/2 [==============================] - 3s 1s/step
# 1/1 [==============================] - 4s 4s/step
#
# ================================================================================
# Validation accuracy after fine-tuning: 0.7164
# Validation precision after fine-tuning: 0.7049
# Validation recall after fine-tuning: 0.6767
# Validation F1 score after fine-tuning: 0.6783
# ================================================================================
#
# Fold 4
# Found 2684 files belonging to 4 classes.
# Using 2148 files for training.
# Found 2684 files belonging to 4 classes.
# Using 536 files for validation.
# Epoch 1/30
# 34/34 - 191s - loss: 1.2292 - accuracy: 0.5787 - val_loss: 0.9580 - val_accuracy: 0.5989 - 191s/epoch - 6s/step
# Epoch 2/30
# 34/34 - 180s - loss: 0.7873 - accuracy: 0.6890 - val_loss: 0.8837 - val_accuracy: 0.6530 - 180s/epoch - 5s/step
# Epoch 3/30
# 34/34 - 179s - loss: 0.7005 - accuracy: 0.7086 - val_loss: 1.2855 - val_accuracy: 0.5784 - 179s/epoch - 5s/step
# Epoch 4/30
# 34/34 - 180s - loss: 0.6316 - accuracy: 0.7500 - val_loss: 0.9508 - val_accuracy: 0.5522 - 180s/epoch - 5s/step
# Epoch 5/30
# 34/34 - 180s - loss: 0.5855 - accuracy: 0.7598 - val_loss: 0.7967 - val_accuracy: 0.6847 - 180s/epoch - 5s/step
# Epoch 6/30
# 34/34 - 181s - loss: 0.5272 - accuracy: 0.7928 - val_loss: 0.8749 - val_accuracy: 0.6866 - 181s/epoch - 5s/step
# Epoch 7/30
# 34/34 - 181s - loss: 0.4742 - accuracy: 0.8073 - val_loss: 0.7674 - val_accuracy: 0.7295 - 181s/epoch - 5s/step
# Epoch 8/30
# 34/34 - 181s - loss: 0.4353 - accuracy: 0.8310 - val_loss: 0.7149 - val_accuracy: 0.7425 - 181s/epoch - 5s/step
# Epoch 9/30
# 34/34 - 182s - loss: 0.3728 - accuracy: 0.8515 - val_loss: 0.7524 - val_accuracy: 0.7052 - 182s/epoch - 5s/step
# Epoch 10/30
# 34/34 - 181s - loss: 0.3496 - accuracy: 0.8543 - val_loss: 0.8636 - val_accuracy: 0.7146 - 181s/epoch - 5s/step
# Epoch 11/30
# 34/34 - 184s - loss: 0.3205 - accuracy: 0.8776 - val_loss: 0.8393 - val_accuracy: 0.7071 - 184s/epoch - 5s/step
# Epoch 12/30
# 34/34 - 183s - loss: 0.2913 - accuracy: 0.8920 - val_loss: 0.7298 - val_accuracy: 0.7556 - 183s/epoch - 5s/step
# Epoch 13/30
# 34/34 - 183s - loss: 0.2622 - accuracy: 0.8980 - val_loss: 0.9489 - val_accuracy: 0.7052 - 183s/epoch - 5s/step
# Epoch 14/30
# 34/34 - 184s - loss: 0.2423 - accuracy: 0.9027 - val_loss: 0.9359 - val_accuracy: 0.6623 - 184s/epoch - 5s/step
# Epoch 15/30
# 34/34 - 183s - loss: 0.2196 - accuracy: 0.9190 - val_loss: 1.0320 - val_accuracy: 0.7034 - 183s/epoch - 5s/step
# Epoch 16/30
# 34/34 - 184s - loss: 0.1968 - accuracy: 0.9306 - val_loss: 0.9125 - val_accuracy: 0.7537 - 184s/epoch - 5s/step
# Epoch 17/30
# 34/34 - 180s - loss: 0.1797 - accuracy: 0.9404 - val_loss: 0.9960 - val_accuracy: 0.7257 - 180s/epoch - 5s/step
# Epoch 18/30
# 34/34 - 184s - loss: 0.1766 - accuracy: 0.9334 - val_loss: 1.4819 - val_accuracy: 0.6735 - 184s/epoch - 5s/step
# Epoch 19/30
# 34/34 - 181s - loss: 0.1613 - accuracy: 0.9385 - val_loss: 1.7665 - val_accuracy: 0.6754 - 181s/epoch - 5s/step
# Epoch 20/30
# 34/34 - 183s - loss: 0.1497 - accuracy: 0.9469 - val_loss: 1.0091 - val_accuracy: 0.7444 - 183s/epoch - 5s/step
# Epoch 21/30
# 34/34 - 184s - loss: 0.1317 - accuracy: 0.9483 - val_loss: 1.2493 - val_accuracy: 0.7146 - 184s/epoch - 5s/step
# Epoch 22/30
# 34/34 - 181s - loss: 0.1286 - accuracy: 0.9516 - val_loss: 1.7968 - val_accuracy: 0.6698 - 181s/epoch - 5s/step
# Epoch 23/30
# 34/34 - 182s - loss: 0.1290 - accuracy: 0.9534 - val_loss: 1.1752 - val_accuracy: 0.7108 - 182s/epoch - 5s/step
# Epoch 24/30
# 34/34 - 183s - loss: 0.1117 - accuracy: 0.9632 - val_loss: 1.1112 - val_accuracy: 0.7183 - 183s/epoch - 5s/step
# Epoch 25/30
# 34/34 - 183s - loss: 0.1230 - accuracy: 0.9558 - val_loss: 1.4502 - val_accuracy: 0.7127 - 183s/epoch - 5s/step
# Epoch 26/30
# 34/34 - 182s - loss: 0.1234 - accuracy: 0.9604 - val_loss: 1.2596 - val_accuracy: 0.7369 - 182s/epoch - 5s/step
# Epoch 27/30
# 34/34 - 182s - loss: 0.1025 - accuracy: 0.9614 - val_loss: 1.3616 - val_accuracy: 0.7108 - 182s/epoch - 5s/step
# Epoch 28/30
# 34/34 - 180s - loss: 0.0939 - accuracy: 0.9637 - val_loss: 1.5104 - val_accuracy: 0.7201 - 180s/epoch - 5s/step
# Epoch 29/30
# 34/34 - 183s - loss: 0.0930 - accuracy: 0.9637 - val_loss: 1.7518 - val_accuracy: 0.7183 - 183s/epoch - 5s/step
# Epoch 30/30
# 34/34 - 182s - loss: 0.0953 - accuracy: 0.9614 - val_loss: 1.4609 - val_accuracy: 0.7052 - 182s/epoch - 5s/step
# 2/2 [==============================] - 5s 1s/step
# 2/2 [==============================] - 3s 1s/step
# 2/2 [==============================] - 3s 1s/step
# 2/2 [==============================] - 3s 2s/step
# 2/2 [==============================] - 4s 2s/step
# 2/2 [==============================] - 4s 2s/step
# 2/2 [==============================] - 2s 1s/step
# 2/2 [==============================] - 3s 1s/step
# 1/1 [==============================] - 3s 3s/step
#
# ================================================================================
# Validation accuracy after fine-tuning: 0.7052
# Validation precision after fine-tuning: 0.7161
# Validation recall after fine-tuning: 0.6643
# Validation F1 score after fine-tuning: 0.6585
# ================================================================================
#
# Fold 5
# Found 2684 files belonging to 4 classes.
# Using 2148 files for training.
# Found 2684 files belonging to 4 classes.
# Using 536 files for validation.
# Epoch 1/30
# 34/34 - 191s - loss: 1.1383 - accuracy: 0.5838 - val_loss: 0.9995 - val_accuracy: 0.5858 - 191s/epoch - 6s/step
# Epoch 2/30
# 34/34 - 185s - loss: 0.7740 - accuracy: 0.6918 - val_loss: 1.0869 - val_accuracy: 0.5299 - 185s/epoch - 5s/step
# Epoch 3/30
# 34/34 - 184s - loss: 0.6651 - accuracy: 0.7272 - val_loss: 1.0366 - val_accuracy: 0.6138 - 184s/epoch - 5s/step
# Epoch 4/30
# 34/34 - 182s - loss: 0.6309 - accuracy: 0.7444 - val_loss: 0.9011 - val_accuracy: 0.6306 - 182s/epoch - 5s/step
# Epoch 5/30
# 34/34 - 182s - loss: 0.5807 - accuracy: 0.7668 - val_loss: 0.8121 - val_accuracy: 0.6903 - 182s/epoch - 5s/step
# Epoch 6/30
# 34/34 - 183s - loss: 0.5240 - accuracy: 0.7863 - val_loss: 0.8090 - val_accuracy: 0.6903 - 183s/epoch - 5s/step
# Epoch 7/30
# 34/34 - 186s - loss: 0.4984 - accuracy: 0.7961 - val_loss: 0.8854 - val_accuracy: 0.6791 - 186s/epoch - 5s/step
# Epoch 8/30
# 34/34 - 185s - loss: 0.4422 - accuracy: 0.8264 - val_loss: 0.7813 - val_accuracy: 0.7052 - 185s/epoch - 5s/step
# Epoch 9/30
# 34/34 - 181s - loss: 0.3969 - accuracy: 0.8361 - val_loss: 0.8490 - val_accuracy: 0.7015 - 181s/epoch - 5s/step
# Epoch 10/30
# 34/34 - 184s - loss: 0.3640 - accuracy: 0.8603 - val_loss: 0.9008 - val_accuracy: 0.7034 - 184s/epoch - 5s/step
# Epoch 11/30
# 34/34 - 183s - loss: 0.3427 - accuracy: 0.8631 - val_loss: 0.7874 - val_accuracy: 0.7183 - 183s/epoch - 5s/step
# Epoch 12/30
# 34/34 - 183s - loss: 0.3012 - accuracy: 0.8836 - val_loss: 0.8001 - val_accuracy: 0.7220 - 183s/epoch - 5s/step
# Epoch 13/30
# 34/34 - 185s - loss: 0.2897 - accuracy: 0.8850 - val_loss: 0.8202 - val_accuracy: 0.7463 - 185s/epoch - 5s/step
# Epoch 14/30
# 34/34 - 183s - loss: 0.2474 - accuracy: 0.9060 - val_loss: 0.8213 - val_accuracy: 0.7127 - 183s/epoch - 5s/step
# Epoch 15/30
# 34/34 - 185s - loss: 0.2558 - accuracy: 0.8985 - val_loss: 0.9303 - val_accuracy: 0.7481 - 185s/epoch - 5s/step
# Epoch 16/30
# 34/34 - 181s - loss: 0.2039 - accuracy: 0.9241 - val_loss: 0.9674 - val_accuracy: 0.7351 - 181s/epoch - 5s/step
# Epoch 17/30
# 34/34 - 183s - loss: 0.1897 - accuracy: 0.9255 - val_loss: 1.0930 - val_accuracy: 0.6922 - 183s/epoch - 5s/step
# Epoch 18/30
# 34/34 - 183s - loss: 0.1950 - accuracy: 0.9255 - val_loss: 0.9393 - val_accuracy: 0.7463 - 183s/epoch - 5s/step
# Epoch 19/30
# 34/34 - 184s - loss: 0.1609 - accuracy: 0.9432 - val_loss: 1.0780 - val_accuracy: 0.7108 - 184s/epoch - 5s/step
# Epoch 20/30
# 34/34 - 185s - loss: 0.1918 - accuracy: 0.9311 - val_loss: 1.0406 - val_accuracy: 0.7295 - 185s/epoch - 5s/step
# Epoch 21/30
# 34/34 - 184s - loss: 0.1289 - accuracy: 0.9534 - val_loss: 1.1072 - val_accuracy: 0.6940 - 184s/epoch - 5s/step
# Epoch 22/30
# 34/34 - 185s - loss: 0.1449 - accuracy: 0.9423 - val_loss: 1.2681 - val_accuracy: 0.7090 - 185s/epoch - 5s/step
# Epoch 23/30
# 34/34 - 184s - loss: 0.1367 - accuracy: 0.9534 - val_loss: 1.2001 - val_accuracy: 0.7052 - 184s/epoch - 5s/step
# Epoch 24/30
# 34/34 - 183s - loss: 0.1276 - accuracy: 0.9525 - val_loss: 1.3310 - val_accuracy: 0.6847 - 183s/epoch - 5s/step
# Epoch 25/30
# 34/34 - 184s - loss: 0.1306 - accuracy: 0.9567 - val_loss: 1.2832 - val_accuracy: 0.7164 - 184s/epoch - 5s/step
# Epoch 26/30
# 34/34 - 185s - loss: 0.1196 - accuracy: 0.9525 - val_loss: 1.0544 - val_accuracy: 0.7295 - 185s/epoch - 5s/step
# Epoch 27/30
# 34/34 - 185s - loss: 0.1141 - accuracy: 0.9572 - val_loss: 1.4559 - val_accuracy: 0.7239 - 185s/epoch - 5s/step
# Epoch 28/30
# 34/34 - 183s - loss: 0.1371 - accuracy: 0.9548 - val_loss: 1.2029 - val_accuracy: 0.7500 - 183s/epoch - 5s/step
# Epoch 29/30
# 34/34 - 185s - loss: 0.0985 - accuracy: 0.9628 - val_loss: 1.4583 - val_accuracy: 0.7239 - 185s/epoch - 5s/step
# Epoch 30/30
# 34/34 - 183s - loss: 0.1109 - accuracy: 0.9623 - val_loss: 1.1395 - val_accuracy: 0.7220 - 183s/epoch - 5s/step
# 2/2 [==============================] - 4s 1s/step
# 2/2 [==============================] - 3s 1s/step
# 2/2 [==============================] - 3s 1s/step
# 2/2 [==============================] - 3s 1s/step
# 2/2 [==============================] - 4s 2s/step
# 2/2 [==============================] - 3s 1s/step
# 2/2 [==============================] - 4s 2s/step
# 2/2 [==============================] - 3s 1s/step
# 1/1 [==============================] - 3s 3s/step
#
# ================================================================================
# Validation accuracy after fine-tuning: 0.7220
# Validation precision after fine-tuning: 0.7001
# Validation recall after fine-tuning: 0.7013
# Validation F1 score after fine-tuning: 0.6975
# ================================================================================
#
#
# ================================================================================
# Average accuracy: 0.7198
# Average precision: 0.7092
# Average recall: 0.6855
# Average F1 score: 0.6815

# %%
from sklearn.metrics import confusion_matrix

# create empty arrays for y_true and y_pred
y_true_all = []
y_pred_all = []

for i, (train_idx, val_idx) in enumerate(kf.split(train_dir)):
    # ... omitted code for clarity ...

    # Evaluate the model on the validation dataset
    y_true = []
    y_pred = []
    for images, labels in val_ds:
        pred = model.predict(images)
        y_true.extend(tf.argmax(labels, axis=1))
        y_pred.extend(tf.argmax(pred, axis=1))

    y_true_all.extend(y_true)
    y_pred_all.extend(y_pred)

    # ... omitted code for clarity ...

# Calculate the confusion matrix across all folds
cm = confusion_matrix(y_true_all, y_pred_all)

sns.heatmap(cm, annot=True, cmap="Blues", fmt="d", xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()
# Out:
# 2/2 [==============================] - 3s 2s/step
# 2/2 [==============================] - 4s 2s/step
# 2/2 [==============================] - 3s 1s/step
# 2/2 [==============================] - 3s 1s/step
# 2/2 [==============================] - 3s 1s/step
# 2/2 [==============================] - 3s 1s/step
# 2/2 [==============================] - 3s 2s/step
# 2/2 [==============================] - 4s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 2/2 [==============================] - 3s 1s/step
# 2/2 [==============================] - 3s 1s/step
# 2/2 [==============================] - 3s 2s/step
# 2/2 [==============================] - 3s 2s/step
# 2/2 [==============================] - 4s 2s/step
# 2/2 [==============================] - 2s 1s/step
# 2/2 [==============================] - 3s 2s/step
# 2/2 [==============================] - 4s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 2/2 [==============================] - 3s 1s/step
# 2/2 [==============================] - 3s 1s/step
# 2/2 [==============================] - 4s 2s/step
# 2/2 [==============================] - 4s 1s/step
# 2/2 [==============================] - 4s 2s/step
# 2/2 [==============================] - 3s 1s/step
# 2/2 [==============================] - 2s 1s/step
# 2/2 [==============================] - 2s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 2/2 [==============================] - 3s 1s/step
# 2/2 [==============================] - 3s 1s/step
# 2/2 [==============================] - 3s 1s/step
# 2/2 [==============================] - 3s 1s/step
# 2/2 [==============================] - 3s 2s/step
# 2/2 [==============================] - 3s 2s/step
# 2/2 [==============================] - 3s 1s/step
# 2/2 [==============================] - 3s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 2/2 [==============================] - 3s 1s/step
# 2/2 [==============================] - 3s 1s/step
# 2/2 [==============================] - 3s 1s/step
# 2/2 [==============================] - 3s 1s/step
# 2/2 [==============================] - 3s 2s/step
# 2/2 [==============================] - 4s 2s/step
# 2/2 [==============================] - 3s 1s/step
# 2/2 [==============================] - 3s 1s/step
# 1/1 [==============================] - 1s 1s/step
